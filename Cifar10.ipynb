# %% [markdown]
# <a href="https://colab.research.google.com/github/filmerxyz/CIFAR-10_experiments/blob/master/Cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import models
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, Dense, MaxPooling2D, Dropout, Activation, Flatten, GlobalAveragePooling2D
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.applications.imagenet_utils import preprocess_input
# from tensorflow.keras.applications.nasnet import decode_predictions
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras.datasets import cifar10

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Parameters

# %%
img_width = 32
img_height = 32
num_classes = 10
batch_size = 32
epochs = 100

# %% [markdown]
# # The data, split between train and test sets:

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# # See shape

# %%
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
img_rows, img_cols , channels= 32,32,3
for i in range(0,9):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i])
plt.show()

# %% [markdown]
# # Augmentation

# %%
datagen = ImageDataGenerator(
    rotation_range=15,
    horizontal_flip=True,
    vertical_flip=True,
    zoom_range=0.3
    )
datagen.fit(x_train)

# %%
for X_batch, y_batch in datagen.flow(x_train, y_train, batch_size=9):
    for i in range(0, 9):
        plt.subplot(330 + 1 + i)
        plt.imshow(X_batch[i].astype(np.uint8))
    plt.show()
    break

# %% [markdown]
# # One how encoding

# %%
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# # Normalize

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %% [markdown]
# # Steps

# %%
train_steps_per_epoch = x_train.shape[0] // batch_size
val_steps_per_epoch = x_test.shape[0] // batch_size

# %% [markdown]
# # Model

# %%
base_model = tf.keras.applications.DenseNet201(include_top=False, weights='imagenet', input_shape=x_train.shape[1:])

# %%
len(base_model.layers)
# Out:
# 707

# %%
# base_model.summary()

# %% [markdown]
# # Fine Tune

# %% [markdown]
# Freeze layer

# %%
for layer in base_model.layers[481:]:
  layer.trainable = False

# %%
# base_model.summary()

# %%
average_pooling_layer = GlobalAveragePooling2D()(base_model.output)
dense1 = Dense(1024, activation='relu')(average_pooling_layer)
dense2 = Dense(512, activation='relu')(dense1)
dense3 = Dense(256, activation='relu')(dense2)
dense4 = Dense(128, activation='relu')(dense3)
dense5 = Dense(64, activation='relu')(dense4)
dropout1 = Dropout(0.2)(dense5)
prediction_layer = Dense(units=num_classes, activation='softmax', name='prediction')(dropout1)
model = tf.keras.models.Model(inputs=base_model.input, outputs=prediction_layer)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# model.summary()

# %% [markdown]
# # Callbacks

# %%
early_stop = EarlyStopping(monitor='val_loss',
                           min_delta=0,
                           patience=2,
                           verbose=0, 
                           mode='auto')

# %%
cb_list = [early_stop]

# %%
history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data=(x_test, y_test),
          callbacks=cb_list)
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 105s 67ms/step - loss: 1.3635 - accuracy: 0.5057 - val_loss: 1.0710 - val_accuracy: 0.6382
# Epoch 2/100
# 1563/1563 [==============================] - 101s 65ms/step - loss: 0.9038 - accuracy: 0.7023 - val_loss: 0.9905 - val_accuracy: 0.6849
# Epoch 3/100
# 1563/1563 [==============================] - 101s 65ms/step - loss: 0.7367 - accuracy: 0.7607 - val_loss: 1.0810 - val_accuracy: 0.6297
# Epoch 4/100
# 1563/1563 [==============================] - 101s 65ms/step - loss: 0.6407 - accuracy: 0.7933 - val_loss: 0.8430 - val_accuracy: 0.7321
# Epoch 5/100
# 1563/1563 [==============================] - 102s 65ms/step - loss: 0.5663 - accuracy: 0.8182 - val_loss: 0.7417 - val_accuracy: 0.7634
# Epoch 6/100
# 1563/1563 [==============================] - 102s 65ms/step - loss: 0.5137 - accuracy: 0.8346 - val_loss: 0.7748 - val_accuracy: 0.7511
# Epoch 7/100
# 1563/1563 [==============================] - 102s 65ms/step - loss: 0.4642 - accuracy: 0.8508 - val_loss: 0.7531 - val_accuracy: 0.7601

# %% [markdown]
# # Graph

# %% [markdown]
# **Accuracy**

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('accuracy')
plt.show()

# %% [markdown]
# **Loss**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('loss')
plt.show()

# %% [markdown]
# # Scores

# %%
scores = model.evaluate(x_test, y_test, verbose=1)
# Out:
# 313/313 [==============================] - 8s 25ms/step - loss: 0.7531 - accuracy: 0.7601

# %%
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Test loss: 0.7531307935714722
# Test accuracy: 0.7601000070571899
